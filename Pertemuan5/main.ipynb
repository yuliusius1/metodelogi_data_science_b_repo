# %% [markdown]
# # Data Gathering
# Kita akan ambil dari Kaggle, Dibutuhkan API. Silahkan unduh library Kaggle terlebih dahulu

# %% [markdown]
# ### Instalasi Kaggle

# %%
# !pip install kaggle

# %% [markdown]
# ### Unduh dataset dari kaggle

# %%
# !kaggle datasets download shreyanshkhandelwal/goal-dataset-top-5-european-leagues
# Out:
# goal-dataset-top-5-european-leagues.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ### Import Library Pandas and Numpy

# %%
import pandas as pd
import numpy as np

# %%
path = "goal-dataset-top-5-european-leagues/epl-goalScorer(20-21).csv"
df = pd.read_csv(path)

# %%
df
# Out:
#      Unnamed: 0    id             player_name  games  time  goals         xG  \
# 0             0   647              Harry Kane     35  3097     23  22.174859
# 1             1  1250           Mohamed Salah     37  3085     22  20.250847
# 2             2  1228         Bruno Fernandes     37  3117     18  16.019454
# 3             3   453           Son Heung-Min     37  3139     17  11.023287
# 4             4   822         Patrick Bamford     38  3085     17  18.401863
# ..          ...   ...                     ...    ...   ...    ...        ...
# 517         517  9415  Jaden Philogene-Bidace      1     1      0   0.000000
# 518         518  9423         Gaetano Berardi      2   113      0   0.074761
# 519         519  9524          Anthony Elanga      1    67      0   0.000000
# 520         520  9540             Femi Seriki      1     1      0   0.000000
# 521         521  9552         Tyrese Francois      1    13      0   0.000000
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %%
df_tanpaid = df.iloc[1:,1:]
df_tanpaid
# Out:
#        id             player_name  games  time  goals         xG  assists  \
# 1    1250           Mohamed Salah     37  3085     22  20.250847        5
# 2    1228         Bruno Fernandes     37  3117     18  16.019454       12
# 3     453           Son Heung-Min     37  3139     17  11.023287       10
# 4     822         Patrick Bamford     38  3085     17  18.401863        7
# 5    5555   Dominic Calvert-Lewin     32  2788     16  18.136449        0
# ..    ...                     ...    ...   ...    ...        ...      ...
# 517  9415  Jaden Philogene-Bidace      1     1      0   0.000000        0
# 518  9423         Gaetano Berardi      2   113      0   0.074761        0
# 519  9524          Anthony Elanga      1    67      0   0.000000        0
# 520  9540             Femi Seriki      1     1      0   0.000000        0
# 521  9552         Tyrese Francois      1    13      0   0.000000        0
#
#             xA  shots  key_passes  yellow_cards  red_cards position  \
# ...

# %%
df_rapi = df_tanpaid.sort_values(by="player_name", ascending=True)
df_rapi.head(15)
# Out:
#        id             player_name  games  time  goals        xG  assists  \
# 154  7991          Aaron Connolly     16   755      2  4.412464        1
# 281   534         Aaron Cresswell     35  3086      0  0.883464        8
# 390  5603          Aaron Ramsdale     37  3330      0  0.000000        0
# 139  5584       Aaron Wan-Bissaka     34  3060      2  0.932454        4
# 126  1726      Abdoulaye Doucouré     28  2409      2  2.369523        3
# 380  4866        Aboubakar Kamara     11   303      0  0.654920        0
# 163   486            Adam Lallana     29  1528      1  1.614306        1
# 242  7699            Adam Webster     28  2506      1  1.272957        0
# 119   900            Adama Traoré     36  2604      2  1.995262        2
# 75   5556         Ademola Lookman     34  2765      4  6.251116        4
# 278   527                  Adrián      3   270      0  0.000000        0
# 345  1685        Ahmed Elmohamady     14   823      0  0.341273        0
# ...

# %%
df_rapi = df_tanpaid.sort_values(by="assist", ascending=True)
df_rapi.head(15)
